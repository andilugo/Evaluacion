# %% [markdown]
# <a href="https://colab.research.google.com/github/andilugo/Evaluacion/blob/main/Evaluaci%C3%B3n_Etapa_2_Espa%C3%B1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluación Etapa 2
# Andrea Cosset Hernández Lugo A01707744

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Girona_España**

# %%
esp = pd.read_csv("Girona_España_clean.csv")
esp
# Out:
# <ipython-input-11-a6480f18c27b>:1: DtypeWarning: Columns (0,1,3,9,25,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   esp = pd.read_csv("Girona_España_clean.csv")
#       Unnamed: 0                    id  \
# 0              0                 14551
# 1              1               1205757
# 2              2               1212820
# 3              3                751638
# 4              4                 41342
# ...          ...                   ...
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19653      19652  858000000000000000.0
# 19654      19653  858000000000000000.0
# 19655      19654  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 1                 https://www.airbnb.com/rooms/1205757       2.02303E+13
# 2                 https://www.airbnb.com/rooms/1212820       2.02303E+13
# ...

# %% [markdown]
# ## Filtro a) host_acceptance_rate> 50%

# %%
filtroA = esp.loc[esp['host_acceptance_rate'] > 0.50]
filtroA
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 2              2               1212820
# 3              3                751638
# 5              5                751997
# 6              6                752035
# ...          ...                   ...
# 19648      19647  858000000000000000.0
# 19649      19648  858000000000000000.0
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19654      19653  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 2                 https://www.airbnb.com/rooms/1212820       2.02303E+13
# 3                  https://www.airbnb.com/rooms/751638       2.02303E+13
# 5                  https://www.airbnb.com/rooms/751997       2.02303E+13
# 6                  https://www.airbnb.com/rooms/752035       2.02303E+13
# ...

# %% [markdown]
# ## Filtro b) Sólo los registros con categoría “superhost”

# %%
filtroB = esp.loc[esp['host_is_superhost'] == 't']
filtroB
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 8              8                 45400
# 10            10                753604
# 21            21                106704
# 23            23                766763
# ...          ...                   ...
# 19598      19597  857000000000000000.0
# 19602      19601  856000000000000000.0
# 19618      19617  857000000000000000.0
# 19629      19628  858000000000000000.0
# 19652      19651  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 8                   https://www.airbnb.com/rooms/45400       2.02303E+13
# 10                 https://www.airbnb.com/rooms/753604       2.02303E+13
# 21                 https://www.airbnb.com/rooms/106704       2.02303E+13
# 23                 https://www.airbnb.com/rooms/766763       2.02303E+13
# ...

# %% [markdown]
# ## Filtro c) Los registros que no hallan verificado identidad “ not identity_verified”

# %%
filtroC = esp.loc[esp['host_identity_verified'] == 'f']
filtroC
# Out:
#       Unnamed: 0                    id  \
# 2              2               1212820
# 7              7               1215790
# 9              9               1222762
# 30            30                784892
# 33            33               1242933
# ...          ...                   ...
# 19554      19553  856000000000000000.0
# 19561      19560  856000000000000000.0
# 19562      19561  856000000000000000.0
# 19612      19611  857000000000000000.0
# 19613      19612  857000000000000000.0
#
#                                            listing_url         scrape_id  \
# 2                 https://www.airbnb.com/rooms/1212820       2.02303E+13
# 7                 https://www.airbnb.com/rooms/1215790       2.02303E+13
# 9                 https://www.airbnb.com/rooms/1222762       2.02303E+13
# 30                 https://www.airbnb.com/rooms/784892       2.02303E+13
# 33                https://www.airbnb.com/rooms/1242933       2.02303E+13
# ...

# %% [markdown]
# ## Filtro d) Los registro cuyo property_type = “Private room” y “Hotel room”

# %%
filtroD= esp.loc[esp['property_type'].isin(['Private room', 'Hotel room'])]
filtroD
# Out:
#       Unnamed: 0                    id  \
# 356          356               3054347
# 2485        2484              14613107
# 3135        3134              17117682
# 7839        7838              32997174
# 16666      16665  658000000000000000.0
# 17058      17057  687000000000000000.0
# 19023      19022  841000000000000000.0
#
#                                            listing_url         scrape_id  \
# 356               https://www.airbnb.com/rooms/3054347       2.02303E+13
# 2485             https://www.airbnb.com/rooms/14613107       2.02303E+13
# 3135             https://www.airbnb.com/rooms/17117682       2.02303E+13
# 7839             https://www.airbnb.com/rooms/32997174       2.02303E+13
# 16666  https://www.airbnb.com/rooms/658304684608776381  20230300000000.0
# 17058  https://www.airbnb.com/rooms/686737674628035786  20230300000000.0
# 19023  https://www.airbnb.com/rooms/841208789516756655  20230300000000.0
#
#       last_scraped           source  \
# ...

# %% [markdown]
# ## Filtro e) Los registros que cuenten con bathroom > 1

# %%
filtroE = esp.loc[esp['bathrooms'] > 1]
filtroE
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## Filtro f) Los registros cuyo precio sea mayor de $10,000 y que sean de tipo “Entire home”

# %%
filtroF = esp.loc[(esp['price'] > 10000) & (esp['property_type'] == 'Entire home')]
filtroF
# Out:
#     Unnamed: 0       id                           listing_url    scrape_id  \
# 753        753  4682669  https://www.airbnb.com/rooms/4682669  2.02303E+13
#
#     last_scraped       source         name  \
# 753     01/04/23  city scrape  Rural house
#
#                                            description  \
# 753  Rural house (Only Adults) with sustainability ...
#
#                                            picture_url   host_id  ...  \
# 753  https://a0.muscache.com/pictures/miso/Hosting-...  24213114  ...
#
#     review_scores_checkin review_scores_communication review_scores_location  \
# 753                   5.0                         5.0                    5.0
#
#     review_scores_value calculated_host_listings_count  \
# 753                 5.0                            2.0
#
#     calculated_host_listings_count_entire_homes  \
# 753                                         2.0
#
#     calculated_host_listings_count_private_rooms  \
# ...

# %% [markdown]
# # Filtro g) Los registros cuyo review_scores_cleanliness > 4.5

# %%
filtroG= esp.loc[esp['review_scores_cleanliness'] > 4.5]
filtroG
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 1              1               1205757
# 4              4                 41342
# 5              5                751997
# 6              6                752035
# ...          ...                   ...
# 18962      18961  833000000000000000.0
# 19002      19001  841000000000000000.0
# 19047      19046  842000000000000000.0
# 19078      19077  842000000000000000.0
# 19203      19202  843000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 1                 https://www.airbnb.com/rooms/1205757       2.02303E+13
# 4                   https://www.airbnb.com/rooms/41342       2.02303E+13
# 5                  https://www.airbnb.com/rooms/751997       2.02303E+13
# 6                  https://www.airbnb.com/rooms/752035       2.02303E+13
# ...

# %% [markdown]
# ## Filtro h) Los registros cuyo review_scores_value > 4.9

# %%
filtroH = esp.loc[esp['review_scores_value'] > 4.9]
filtroH
# Out:
#       Unnamed: 0                    id  \
# 22            22               1234785
# 26            26                774371
# 40            40               1250062
# 43            43                809136
# 53            53               1262051
# ...          ...                   ...
# 19039      19038  841000000000000000.0
# 19047      19046  842000000000000000.0
# 19078      19077  842000000000000000.0
# 19203      19202  843000000000000000.0
# 19468      19467  850000000000000000.0
#
#                                            listing_url         scrape_id  \
# 22                https://www.airbnb.com/rooms/1234785       2.02303E+13
# 26                 https://www.airbnb.com/rooms/774371       2.02303E+13
# 40                https://www.airbnb.com/rooms/1250062       2.02303E+13
# 43                 https://www.airbnb.com/rooms/809136       2.02303E+13
# 53                https://www.airbnb.com/rooms/1262051       2.02303E+13
# ...

# %% [markdown]
# ## Filtro i) Los registros cuya availability_365< 100

# %%
filtroI = esp.loc[esp['availability_365'] < 100]
filtroI
# Out:
#       Unnamed: 0                    id  \
# 4              4                 41342
# 7              7               1215790
# 11            11                 48764
# 15            15                 93343
# 20            20               1234784
# ...          ...                   ...
# 19628      19627  858000000000000000.0
# 19633      19632  858000000000000000.0
# 19635      19634  858000000000000000.0
# 19639      19638  858000000000000000.0
# 19655      19654  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 4                   https://www.airbnb.com/rooms/41342       2.02303E+13
# 7                 https://www.airbnb.com/rooms/1215790       2.02303E+13
# 11                  https://www.airbnb.com/rooms/48764       2.02303E+13
# 15                  https://www.airbnb.com/rooms/93343       2.02303E+13
# 20                https://www.airbnb.com/rooms/1234784       2.02303E+13
# ...

# %% [markdown]
# ## Filtro j) Los registros cuya host_response_time sea “within an hour”

# %%
filtroJ = esp.loc[esp['host_response_time'] == 'within an hour']
filtroJ
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 5              5                751997
# 6              6                752035
# 8              8                 45400
# 10            10                753604
# ...          ...                   ...
# 19648      19647  858000000000000000.0
# 19649      19648  858000000000000000.0
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19654      19653  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 5                  https://www.airbnb.com/rooms/751997       2.02303E+13
# 6                  https://www.airbnb.com/rooms/752035       2.02303E+13
# 8                   https://www.airbnb.com/rooms/45400       2.02303E+13
# 10                 https://www.airbnb.com/rooms/753604       2.02303E+13
# ...

# %%
#Convertir DataFrame a CSV
filtroA.to_csv("FiltroA_esp.csv")
filtroB.to_csv("FiltroB_esp.csv")
filtroC.to_csv("FiltroC_esp.csv")
filtroD.to_csv("FiltroD_esp.csv")
filtroE.to_csv("FiltroE_esp.csv")
filtroF.to_csv("FiltroF_esp.csv")
filtroG.to_csv("FiltroG_esp.csv")
filtroH.to_csv("FiltroH_esp.csv")
filtroI.to_csv("FiltroI_esp.csv")
filtroJ.to_csv("FiltroJ_esp.csv")

#descargar archivo filtrado en csv
from google.colab import files 
  
files.download("FiltroA_esp.csv")
files.download("FiltroB_esp.csv")
files.download("FiltroC_esp.csv")
files.download("FiltroD_esp.csv")
files.download("FiltroE_esp.csv")
files.download("FiltroF_esp.csv")
files.download("FiltroG_esp.csv")
files.download("FiltroH_esp.csv")
files.download("FiltroI_esp.csv")
files.download("FiltroJ_esp.csv")
