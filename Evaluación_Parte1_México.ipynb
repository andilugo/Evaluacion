# %% [markdown]
# <a href="https://colab.research.google.com/github/andilugo/Evaluacion/blob/main/Evaluaci%C3%B3n_Parte1_M%C3%A9xico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluación Parte1 México
# Andrea Cosset Hernández Lugo A01707744

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .csv
mex= pd.read_csv('DF_Mexico.csv')
mex.head(5)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  2056638  https://www.airbnb.com/rooms/2056638  20230329041210   2023-03-30
# 1  2072354  https://www.airbnb.com/rooms/2072354  20230329041210   2023-03-30
# 2   696037   https://www.airbnb.com/rooms/696037  20230329041210   2023-03-29
# 3    35797    https://www.airbnb.com/rooms/35797  20230329041210   2023-03-29
# 4    44616    https://www.airbnb.com/rooms/44616  20230329041210   2023-03-30
#
#         source                                               name  \
# 0  city scrape                 Amplio y luminoso loft en Coyoacán
# 1  city scrape                 Coyoacan Historic Studio Apartment
# 2  city scrape  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3  city scrape                                        Villa Dante
# 4  city scrape                                  CONDESA HAUS  B&B
#
#                                          description  \
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=mex.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3596
# Length: 75, dtype: int64

# %%
valores_nulos.to_csv("valores_nulos.csv")

# %%
#Identificar valores nulos por dataframe
valores_nulostot=mex.isnull().sum().sum()
valores_nulostot
# Out:
# 189609

# %%
#Elimino columnas que tienen todas las filas vacías
mex.drop(["neighbourhood_group_cleansed", "bathrooms", "calendar_updated"], axis=1)
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %%
#datos cualitativos
mex["description"] = mex["description"].fillna("--") 
mex["neiborhood_overview"] = mex["neighborhood_overview"].fillna("--")
mex["host_name"] = mex["host_name"].fillna("--")
mex["host_since"] = mex["host_since"].fillna("--")
mex["host_location"] = mex["host_location"].fillna("--")
mex["host_about"] = mex["host_about"].fillna("--")
mex["host_response_time"] = mex["host_response_time"].fillna("--")
mex["host_is_superhost"] = mex["host_is_superhost"].fillna("--")
mex["host_thumbnail_url"] = mex["host_thumbnail_url"].fillna("--")
mex["host_picture_url"] = mex["host_picture_url"].fillna("--")
mex["host_thumbnail_url"] = mex["host_thumbnail_url"].fillna("--")
mex["host_has_profile_pic"] = mex["host_has_profile_pic"].fillna("--")
mex["host_identity_verified"] = mex["host_identity_verified"].fillna("--")
mex["neighbourhood"] = mex["neighbourhood"].fillna("--")
mex["bathrooms_text"] = mex["bathrooms_text"].fillna("--")
mex["first_review"] = mex["first_review"].fillna("--")
mex["last_review"] = mex["last_review"].fillna("--")
mex["license"] = mex["license"].fillna("--")
mex["host_response_rate"] = mex["host_response_rate"].fillna("0%")
mex["host_acceptance_rate"] = mex["host_acceptance_rate"].fillna("0%")

# %%
#datos cuantitativos remplazar por 0 
mex = mex.fillna(0)

# %%
#Corroboramos valores nulos en las columnas
valores_nulos = mex.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# neiborhood_overview                             0
# Length: 76, dtype: int64

# %%
#Corroboramos valores nulos por dataframe
valores_nulos=mex.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %%
#Instalamos librería para análisis de variables categóricas
# !pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
from seaborn import load_dataset
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Separamos temporalmente las columnas cualitativas para llevar a cabo la eliminación de outliers de las columnas cuantitativas
mex_cuanti=mex.drop(['id','listing_url','scrape_id','bedrooms','last_scraped','source','name','description', 'picture_url','host_id','host_url','host_name','host_since','host_location','host_about','host_response_time','host_response_rate','host_is_superhost', 'host_thumbnail_url','host_picture_url','host_neighbourhood','host_total_listings_count','host_verifications', 'host_has_profile_pic', 'host_identity_verified','neighbourhood','neighbourhood_cleansed','neighbourhood_group_cleansed','property_type','room_type','bathrooms_text','amenities','has_availability','calendar_last_scraped','first_review','last_review','license','instant_bookable',], axis=1)
mex_cuanti
# Out:
#                                    neighborhood_overview host_acceptance_rate  \
# 0                                                      0                   0%
# 1      Located in Coyoacan, in a quiet neighborhood w...                   0%
# 2      This area is called Nuevo Polanco, it has bein...                  90%
# 3      Centro comercial Santa Fe, parque interlomas y...                   0%
# 4                                                      0                  86%
# ...                                                  ...                  ...
# 24219                                                  0                 100%
# 24220                                                  0                   0%
# 24221                                                  0                  96%
# 24222                                                  0                 100%
# 24223  Una zona muy bonita ya que varias de las atrac...                 100%
#
# ...

# %%
mex_cuali=mex.drop(['host_response_rate'	,'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count','latitude','longitude','accommodates','beds','price','minimum_nights','maximum_nights','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','availability_30','availability_60','availability_90','availability_365','number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','reviews_per_month', "neighborhood_overview"], axis=1)
mex_cuali
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=mex_cuanti
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# <ipython-input-43-eb0d5962c2c9>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-43-eb0d5962c2c9>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# Limite superior permitido host_listings_count                              252.830274
# latitude                                          19.532575
# longitude                                        -99.065630
# accommodates                                       9.933140
# ...

# %%
#Encontramos Outliers del Dataframe
outliers= mex_cuanti[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-44-0ceb496bcc68>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= mex_cuanti[(y>Limite_Superior)|(y<Limite_Inferior)]
#       neighborhood_overview host_acceptance_rate  host_listings_count  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 24219                   NaN                  NaN                  NaN
# 24220                   NaN                  NaN                  NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
mex2 = mex_cuanti[(y<=Limite_Superior)&(y>=Limite_Inferior)]
mex2
# Out:
# <ipython-input-45-b85f4f6c64dd>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   mex2 = mex_cuanti[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#       neighborhood_overview host_acceptance_rate  host_listings_count  \
# 0                       NaN                  NaN                  3.0
# 1                       NaN                  NaN                  3.0
# 2                       NaN                  NaN                  4.0
# 3                       NaN                  NaN                  1.0
# 4                       NaN                  NaN                 16.0
# ...                     ...                  ...                  ...
# 24219                   NaN                  NaN                  3.0
# 24220                   NaN                  NaN                  1.0
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=mex_cuanti.isnull().sum()
valores_nulos
# Out:
# neighborhood_overview                           0
# host_acceptance_rate                            0
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=mex_cuanti.copy()
data_clean=data_clean.fillna(round(mex_cuanti.mean(),1))
data_clean
# Out:
# <ipython-input-47-9cb7c9df8cb1>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clean=data_clean.fillna(round(mex_cuanti.mean(),1))
#                                    neighborhood_overview host_acceptance_rate  \
# 0                                                      0                   0%
# 1      Located in Coyoacan, in a quiet neighborhood w...                   0%
# 2      This area is called Nuevo Polanco, it has bein...                  90%
# 3      Centro comercial Santa Fe, parque interlomas y...                   0%
# 4                                                      0                  86%
# ...                                                  ...                  ...
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos

# %%
# Unimos los datas con el dataframe
mex_clean = pd.concat([mex_cuali,mex_cuanti], axis=1)
mex_clean

# %%
#Convertir DataFrame a CSV
mex_clean.to_csv("DF_México_clean.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("DF_México_clean.csv")
